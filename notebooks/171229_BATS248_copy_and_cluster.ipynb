# %% [markdown]
# Initial clustering and mica runs for BATS248

# %%
import pandas as pd
import os
import os.path as op
import shutil

# %%
df = pd.read_csv("/mnt/scgc/simon/simonsproject/info/BATS248_keepers_coassembly_stats_171221.csv")

# %%
for i in ["faa","gff"]:
    if op.exists(op.join('/mnt/scgc/simon/simonsproject/bats248_annotations/',i)) == False:
        os.mkdir(op.join('/mnt/scgc/simon/simonsproject/bats248_annotations/',i))

# %% [markdown]
# count = 0
# for i, l in df.iterrows():
#     sag = l['sample']
#     plate = "-".join(l['sample'].split("-")[:2])
#     faa = op.join("/mnt/scgc/simon/results/postlocos/stepanauskas_2016_simons/",plate,sag,"{}_functional_annotation/Prokka/".format(sag),"{}.faa".format(sag))
#     gff = op.join("/mnt/scgc/simon/results/postlocos/stepanauskas_2016_simons/",plate,sag,"{}_functional_annotation/Prokka/".format(sag),"{}.gff".format(sag))
#     if op.exists(faa):
#         count += 1
#         shutil.copy(faa, "/mnt/scgc/simon/simonsproject/bats248_annotations/faa/")
#         shutil.copy(gff, "/mnt/scgc/simon/simonsproject/bats248_annotations/gff/")
# print(count, "faa files copied over")

# %% [markdown]
# !cat /mnt/scgc/simon/simonsproject/bats248_annotations/faa/*.faa > /mnt/scgc/simon/simonsproject/bats248_annotations/bats248_all_orfs.fasta

# %%
in_fasta = '/mnt/scgc/simon/simonsproject/bats248_annotations/bats248_all_orfs.fasta'
out_fasta = '/mnt/scgc/simon/simonsproject/bats248_annotations/bats248_all_orfs_cdhit_c90.fasta'

# %%
cmd = "cd-hit -i {in_fa} -p 1 -c 0.90 -o {out_fa} -T 50 -M 100000".format(in_fa = in_fasta, out_fa = out_fasta)
outlog = "/home/julia/out/171229_cdhit.out"

print("echo '{cmd}' | qsub -N cdhit -q scgc-route -V -l walltime=3:00:00,ncpus=50,mem=150G -j oe -o {log}".format(cmd = cmd, log=outlog))
# Out:
# echo 'cd-hit -i /mnt/scgc/simon/simonsproject/bats248_annotations/bats248_all_orfs.fasta -p 1 -c 0.90 -o /mnt/scgc/simon/simonsproject/bats248_annotations/bats248_all_orfs_cdhit_c90.fasta -T 50 -M 100000' | qsub -N cdhit -q scgc-route -V -l walltime=3:00:00,ncpus=50,mem=150G -j oe -o /home/julia/out/171229_cdhit.out

# %% [markdown]
# After that's done, we'll cluster the 90% ID clusters to 70% ID, then split them up by cluster into groups ~1000 sequences per file and start a massive array submission.

# %%
from nb_tools import run_cd_hit, cluster_map, readfa
import numpy as np
from collections import defaultdict
import itertools
import fileinput

# %%
out70_fasta = out_fasta.replace(".fasta","_c70.fasta")
out70_fasta
# Out:
# '/mnt/scgc/simon/simonsproject/bats248_annotations/bats248_all_orfs_cdhit_c90_c70.fasta'

# %%
outlist = run_cd_hit(out_fasta, out70_fasta, T=2, c=.70)
# Out:
# Running CD-HIT on /mnt/scgc/simon/simonsproject/bats248_annotations/bats248_all_orfs_cdhit_c90.fasta

# %%
fa, clstr = outlist

# %%
singles = True
cluster_map = defaultdict(list)
with open(clstr) as fh:
    for cluster_start, group in itertools.groupby(fh, lambda l: l[0] == '>'):
        members = []
        rep_seq = ''
        if not cluster_start: 
            for line in group:
                if "*" in line: 
                    rep_seq = line.partition(" ")[0]
                else:
                    members.append(line.partition(" ")[0])
        if len(rep_seq) == 0:
            continue
        
        if singles:
            cluster_map[rep_seq] = members
        elif len(members) > 0:
            cluster_map[rep_seq] = members
        else:
            continue

# %%
len(cluster_map)
# Out:
# 463111

# %%
cluster_map
# Out:
# defaultdict(list,
#             {'AG-908-B16_01149': [],
#              'AG-893-D16_00227': [],
#              'AG-895-G08_00073': [],
#              'AG-909-E04_00816': ['AG-910-F10_00251', 'AG-914-M07_00761'],
#              'AG-896-D14_00412': ['AG-898-M15_01106'],
#              'AG-913-D15_00035': [],
#              'AG-898-N03_00209': ['AG-914-J14_00054'],
#              'AG-914-E04_00189': [],
#              'AG-895-F09_00367': [],
#              'AG-360-P05_00591': ['AG-892-A04_00838', 'AG-919-I04_01233'],
#              'AG-891-O19_00014': [],
#              'AG-911-K11_00125': [],
#              'AG-892-D10_01171': [],
#              'AG-891-J04_00229': [],
#              'AG-909-D02_00019': [],
#              'AG-891-E15_00895': [],
#              'AG-359-A11_00348': [],
#              'AG-907-B17_00607': [],
#              'AG-903-E19_00010': [],
#              'AG-359-E06_00309': ['AG-894-A09_00364'],
#              'AG-360-K05_00452': [],
#              'AG-891-C06_00935': ['AG-892-I21_00399',
#               'AG-900-P23_00255',
#               'AG-907-A02_00070',
#               'AG-908-P09_00486',
#               'AG-914-F09_00592'],
#              'AG-901-E05_01418': ['AG-891-I06_01500',
#               'AG-892-D16_01174',
#               'AG-892-M22_01039',
#               'AG-894-L18_00596',
#               'AG-898-I08_00338',
#               'AG-918-L05_00692'],
#              'AG-359-E11_00178': ['AG-891-K16_00705'],
#              'AG-917-N14_00195': [],
#              'AG-904-B14_00322': ['AG-895-I17_00353', 'AG-915-K07_00421'],
#              'AG-892-F18_00448': ['AG-910-D09_00292'],
#              'AG-920-J21_00040': [],
#              'AG-913-B07_01493': ['AG-912-K11_01227', 'AG-918-A17_00137'],
#              'AG-894-F22_00371': [],
#              'AG-908-K04_00080': [],
#              'AG-901-B10_00483': [],
#              'AG-895-A23_00499': [],
#              'AG-908-P13_00479': [],
#              'AG-359-O10_00468': ['AG-360-F21_00187',
#               'AG-891-J10_00822',
#               'AG-892-C19_00350',
#               'AG-892-O07_00140',
#               'AG-911-M18_00337',
#               'AG-915-E09_00544'],
#              'AG-359-B10_00122': [],
#              'AG-891-J21_01184': ['AG-892-J10_00473'],
#              'AG-891-P22_00243': [],
#              'AG-903-J18_00323': [],
#              'AG-914-K08_00224': [],
#              'AG-913-J08_00176': ['AG-893-G05_02132'],
#              'AG-912-P01_00726': [],
#              'AG-359-N04_00561': [],
#              'AG-915-O18_00064': [],
#              'AG-912-D17_00404': ['AG-914-I16_01049'],
#              'AG-915-O11_00321': [],
#              'AG-914-J16_00415': [],
#              'AG-900-K05_00071': ['AG-907-O13_00785'],
#              'AG-892-D13_00196': [],
#               'AG-905-B09_00057',
#               'AG-905-L16_00006',
#               'AG-907-F21_00479',
#               'AG-907-G14_00107',
#               'AG-908-B06_00179',
#               'AG-908-F08_00481',
#               'AG-909-A06_00029',
#               'AG-911-E05_00358',
#               'AG-912-D17_00144',
#               'AG-912-F04_00023',
#               'AG-913-I06_00270',
#               'AG-913-J14_00454',
#               'AG-915-D22_00232',
#               'AG-915-L04_00239',
#               'AG-916-K14_00604',
#               'AG-916-L09_00032',
#               'AG-916-O03_00133',
#               'AG-918-F23_00997',
#               'AG-919-M05_00533',
#               'AG-919-M08_00537',
#               'AG-920-B06_00902',
#               'AG-920-G10_00301',
#               'AG-920-G17_00208',
#               'AG-920-I07_00762',
#               'AG-920-L18_00443'],
#              'AG-918-J13_00720': [],
#              'AG-918-A19_00844': ['AG-359-P04_00209',
#               'AG-360-A04_00077',
#               'AG-360-G20_00469',
#               'AG-893-J21_00212',
#               'AG-896-O16_00273',
#               'AG-900-I15_00064',
#               'AG-901-O21_00393',
#               'AG-901-O21_00394',
#               'AG-901-P19_00527',
#               'AG-903-D18_00340',
#               'AG-903-E09_00397',
#               'AG-904-F16_00466',
#               'AG-905-B19_00712',
#               'AG-907-F21_00139',
#               'AG-907-K05_00209',
#               'AG-908-B06_00921',
#               'AG-908-K06_00370',
#               'AG-910-O05_00532',
#               'AG-911-N13_00141',
#               'AG-912-A22_00463',
#               'AG-912-C11_00051',
#               'AG-913-F04_00325',
#               'AG-913-M20_00330',
#               'AG-914-D21_00613',
#               'AG-915-N15_00297',
#               'AG-917-P03_00035',
#               'AG-918-F23_00214',
#               'AG-919-D16_00389',
#               'AG-919-F04_00043',
#               'AG-919-M08_00567'],
#              'AG-892-A09_00303': [],
#              'AG-891-M17_00056': [],
#              'AG-891-J15_00762': [],
#              'AG-359-I23_01161': ['AG-891-A21_00813'],
#              'AG-897-E02_00259': [],
#              'AG-359-P04_00792': ['AG-360-A04_00104',
#               'AG-892-C16_00646',
#               'AG-903-M03_00663',
#               'AG-912-A22_00483',
#               'AG-918-I10_00302'],
#              'AG-901-P02_00293': [],
#              'AG-901-E05_00966': [],
#              'AG-920-F04_00157': [],
#              'AG-891-J04_01062': [],
#              'AG-894-J08_00031': [],
#              'AG-896-B08_00022': ['AG-892-E04_00250',
#               'AG-894-C03_00308',
#               'AG-897-G22_01095',
#               'AG-899-P08_00300',
#               'AG-901-F09_00861',
#               'AG-910-M02_00116',
#               'AG-913-E17_01052',
#               'AG-913-I23_00250',
#               'AG-918-L05_00198'],
#              'AG-359-A03_01861': ['AG-359-K15_00036', 'AG-911-A11_01522'],
#              'AG-892-D07_00418': [],
#              'AG-903-G06_00343': [],
#              'AG-359-G09_00976': [],
#              'AG-897-B23_00140': [],
#              'AG-917-N22_00167': [],
#              'AG-901-N10_01876': [],
#              'AG-918-G21_00060': [],
#              'AG-896-A03_00098': [],
#              'AG-920-D21_01023': [],
#              'AG-903-N02_00268': [],
#              'AG-908-F16_00496': [],
#              'AG-359-E17_01075': [],
#              'AG-359-M22_00126': [],
#              'AG-897-C15_00117': [],
#              'AG-913-A08_00174': [],
#              'AG-898-N06_00202': [],
#              'AG-892-E21_00404': ['AG-917-P11_00507'],
#              'AG-893-P03_00006': ['AG-900-D23_00309'],
#              'AG-893-M05_01373': [],
#              'AG-900-F08_00157': [],
#              'AG-896-E02_00164': [],
#              ...})

# %%
# now split the 90% clustered fasta into 800 pieces...

# %%
from pyfaidx import Fasta
from nb_tools import write_fa_record

# %%
fa = Fasta("/mnt/scgc/simon/simonsproject/bats248_annotations/bats248_all_orfs_cdhit_c90.fasta")

# %%
count = 0
number = 0
missing = []
for k in cluster_map:
    seqs = [k] + cluster_map[k]
    count += len(seqs)
    with open("/mnt/scgc/simon/simonsproject/bats248_vs/blastin/bats248_orfs_cdhit90_{}.fasta".format(number), "a") as oh:
        for s in seqs:
            try:
                rec = fa[s]
            except:
                missing.append(s)
                continue
                
            write_fa_record(rec.long_name, str(rec), oh)          

    if count > 1000:
        count = 0
        number += 1
        print("resetting count", number)
# Out:
# resetting count 1
# resetting count 2
# resetting count 3
# resetting count 4
# resetting count 5
# resetting count 6
# resetting count 7
# resetting count 8
# resetting count 9
# resetting count 10
# resetting count 11
# resetting count 12
# resetting count 13
# resetting count 14
# resetting count 15
# resetting count 16
# resetting count 17
# resetting count 18
# resetting count 19
# resetting count 20
# resetting count 21
# resetting count 22
# resetting count 23
# resetting count 24
# resetting count 25
# resetting count 26
# resetting count 27
# resetting count 28
# resetting count 29
# resetting count 30
# resetting count 31
# resetting count 32
# resetting count 33
# resetting count 34
# resetting count 35
# resetting count 36
# resetting count 37
# resetting count 38
# resetting count 39
# resetting count 40
# resetting count 41
# resetting count 42
# resetting count 43
# resetting count 44
# resetting count 45
# resetting count 46
# resetting count 47
# resetting count 48
# resetting count 49
# resetting count 50
# resetting count 51
# resetting count 52
# resetting count 53
# resetting count 54
# resetting count 55
# resetting count 56
# resetting count 57
# resetting count 58
# resetting count 59
# resetting count 60
# resetting count 61
# resetting count 62
# resetting count 63
# resetting count 64
# resetting count 65
# resetting count 66
# resetting count 67
# resetting count 68
# resetting count 69
# resetting count 70
# resetting count 71
# resetting count 72
# resetting count 73
# resetting count 74
# resetting count 75
# resetting count 76
# resetting count 77
# resetting count 78
# resetting count 79
# resetting count 80
# resetting count 81
# resetting count 82
# resetting count 83
# resetting count 84
# resetting count 85
# resetting count 86
# resetting count 87
# resetting count 88
# resetting count 89
# resetting count 90
# resetting count 91
# resetting count 92
# resetting count 93
# resetting count 94
# resetting count 95
# resetting count 96
# resetting count 97
# resetting count 98
# resetting count 99
# resetting count 100
# resetting count 101
# resetting count 102
# resetting count 103
# resetting count 104
# resetting count 105
# resetting count 106
# resetting count 107
# resetting count 108
# resetting count 109
# resetting count 110
# resetting count 111
# resetting count 112
# resetting count 113
# resetting count 114
# resetting count 115
# resetting count 116
# resetting count 117
# resetting count 118
# resetting count 119
# resetting count 120
# resetting count 121
# resetting count 122
# resetting count 123
# resetting count 124
# resetting count 125
# resetting count 126
# resetting count 127
# resetting count 128
# resetting count 129
# resetting count 130
# resetting count 131
# resetting count 132
# resetting count 133
# resetting count 134
# resetting count 135
# resetting count 136
# resetting count 137
# resetting count 138
# resetting count 139
# resetting count 140
# resetting count 141
# resetting count 142
# resetting count 143
# resetting count 144
# resetting count 145
# resetting count 146
# resetting count 147
# resetting count 148
# resetting count 149
# resetting count 150
# resetting count 151
# resetting count 152
# resetting count 153
# resetting count 154
# resetting count 155
# resetting count 156
# resetting count 157
# resetting count 158
# resetting count 159
# resetting count 160
# resetting count 161
# resetting count 162
# resetting count 163
# resetting count 164
# resetting count 165
# resetting count 166
# resetting count 167
# resetting count 168
# resetting count 169
# resetting count 170
# resetting count 171
# resetting count 172
# resetting count 173
# resetting count 174
# resetting count 175
# resetting count 176
# resetting count 177
# resetting count 178
# resetting count 179
# resetting count 180
# resetting count 181
# resetting count 182
# resetting count 183
# resetting count 184
# resetting count 185
# resetting count 186
# resetting count 187
# resetting count 188
# resetting count 189
# resetting count 190
# resetting count 191
# resetting count 192
# resetting count 193
# resetting count 194
# resetting count 195
# resetting count 196
# resetting count 197
# resetting count 198
# resetting count 199
# resetting count 200
# resetting count 201
# resetting count 202
# resetting count 203
# resetting count 204
# resetting count 205
# resetting count 206
# resetting count 207
# resetting count 208
# resetting count 209
# resetting count 210
# resetting count 211
# resetting count 212
# resetting count 213
# resetting count 214
# resetting count 215
# resetting count 216
# resetting count 217
# resetting count 218
# resetting count 219
# resetting count 220
# resetting count 221
# resetting count 222
# resetting count 223
# resetting count 224
# resetting count 225
# resetting count 226
# resetting count 227
# resetting count 228
# resetting count 229
# resetting count 230
# resetting count 231
# resetting count 232
# resetting count 233
# resetting count 234
# resetting count 235
# resetting count 236
# resetting count 237
# resetting count 238
# resetting count 239
# resetting count 240
# resetting count 241
# resetting count 242
# resetting count 243
# resetting count 244
# resetting count 245
# resetting count 246
# resetting count 247
# resetting count 248
# resetting count 249
# resetting count 250
# resetting count 251
# resetting count 252
# resetting count 253
# resetting count 254
# resetting count 255
# resetting count 256
# resetting count 257
# resetting count 258
# resetting count 259
# resetting count 260
# resetting count 261
# resetting count 262
# resetting count 263
# resetting count 264
# resetting count 265
# resetting count 266
# resetting count 267
# resetting count 268
# resetting count 269
# resetting count 270
# resetting count 271
# resetting count 272
# resetting count 273
# resetting count 274
# resetting count 275
# resetting count 276
# resetting count 277
# resetting count 278
# resetting count 279
# resetting count 280
# resetting count 281
# resetting count 282
# resetting count 283
# resetting count 284
# resetting count 285
# resetting count 286
# resetting count 287
# resetting count 288
# resetting count 289
# resetting count 290
# resetting count 291
# resetting count 292
# resetting count 293
# resetting count 294
# resetting count 295
# resetting count 296
# resetting count 297
# resetting count 298
# resetting count 299
# resetting count 300
# resetting count 301
# resetting count 302
# resetting count 303
# resetting count 304
# resetting count 305
# resetting count 306
# resetting count 307
# resetting count 308
# resetting count 309
# resetting count 310
# resetting count 311
# resetting count 312
# resetting count 313
# resetting count 314
# resetting count 315
# resetting count 316
# resetting count 317
# resetting count 318
# resetting count 319
# resetting count 320
# resetting count 321
# resetting count 322
# resetting count 323
# resetting count 324
# resetting count 325
# resetting count 326
# resetting count 327
# resetting count 328
# resetting count 329
# resetting count 330
# resetting count 331
# resetting count 332
# resetting count 333
# resetting count 334
# resetting count 335
# resetting count 336
# resetting count 337
# resetting count 338
# resetting count 339
# resetting count 340
# resetting count 341
# resetting count 342
# resetting count 343
# resetting count 344
# resetting count 345
# resetting count 346
# resetting count 347
# resetting count 348
# resetting count 349
# resetting count 350
# resetting count 351
# resetting count 352
# resetting count 353
# resetting count 354
# resetting count 355
# resetting count 356
# resetting count 357
# resetting count 358
# resetting count 359
# resetting count 360
# resetting count 361
# resetting count 362
# resetting count 363
# resetting count 364
# resetting count 365
# resetting count 366
# resetting count 367
# resetting count 368
# resetting count 369
# resetting count 370
# resetting count 371
# resetting count 372
# resetting count 373
# resetting count 374
# resetting count 375
# resetting count 376
# resetting count 377
# resetting count 378
# resetting count 379
# resetting count 380
# resetting count 381
# resetting count 382
# resetting count 383
# resetting count 384
# resetting count 385
# resetting count 386
# resetting count 387
# resetting count 388
# resetting count 389
# resetting count 390
# resetting count 391
# resetting count 392
# resetting count 393
# resetting count 394
# resetting count 395
# resetting count 396
# resetting count 397
# resetting count 398
# resetting count 399
# resetting count 400
# resetting count 401
# resetting count 402
# resetting count 403
# resetting count 404
# resetting count 405
# resetting count 406
# resetting count 407
# resetting count 408
# resetting count 409
# resetting count 410
# resetting count 411
# resetting count 412
# resetting count 413
# resetting count 414
# resetting count 415
# resetting count 416
# resetting count 417
# resetting count 418
# resetting count 419
# resetting count 420
# resetting count 421
# resetting count 422
# resetting count 423
# resetting count 424
# resetting count 425
# resetting count 426
# resetting count 427
# resetting count 428
# resetting count 429
# resetting count 430
# resetting count 431
# resetting count 432
# resetting count 433
# resetting count 434
# resetting count 435
# resetting count 436
# resetting count 437
# resetting count 438
# resetting count 439
# resetting count 440
# resetting count 441
# resetting count 442
# resetting count 443
# resetting count 444
# resetting count 445
# resetting count 446
# resetting count 447
# resetting count 448
# resetting count 449
# resetting count 450
# resetting count 451
# resetting count 452
# resetting count 453
# resetting count 454
# resetting count 455
# resetting count 456
# resetting count 457
# resetting count 458
# resetting count 459
# resetting count 460
# resetting count 461
# resetting count 462
# resetting count 463
# resetting count 464
# resetting count 465
# resetting count 466
# resetting count 467
# resetting count 468
# resetting count 469
# resetting count 470
# resetting count 471
# resetting count 472
# resetting count 473
# resetting count 474
# resetting count 475
# resetting count 476
# resetting count 477
# resetting count 478
# resetting count 479
# resetting count 480
# resetting count 481
# resetting count 482
# resetting count 483
# resetting count 484
# resetting count 485
# resetting count 486
# resetting count 487
# resetting count 488
# resetting count 489
# resetting count 490
# resetting count 491
# resetting count 492
# resetting count 493
# resetting count 494
# resetting count 495
# resetting count 496
# resetting count 497
# resetting count 498
# resetting count 499
# resetting count 500
# resetting count 501
# resetting count 502
# resetting count 503
# resetting count 504
# resetting count 505
# resetting count 506
# resetting count 507
# resetting count 508
# resetting count 509
# resetting count 510
# resetting count 511
# resetting count 512
# resetting count 513
# resetting count 514
# resetting count 515
# resetting count 516
# resetting count 517
# resetting count 518
# resetting count 519
# resetting count 520
# resetting count 521
# resetting count 522
# resetting count 523
# resetting count 524
# resetting count 525
# resetting count 526
# resetting count 527
# resetting count 528
# resetting count 529
# resetting count 530
# resetting count 531
# resetting count 532
# resetting count 533
# resetting count 534
# resetting count 535
# resetting count 536
# resetting count 537
# resetting count 538
# resetting count 539
# resetting count 540
# resetting count 541
# resetting count 542
# resetting count 543
# resetting count 544
# resetting count 545
# resetting count 546
# resetting count 547
# resetting count 548
# resetting count 549
# resetting count 550
# resetting count 551
# resetting count 552
# resetting count 553
# resetting count 554
# resetting count 555
# resetting count 556
# resetting count 557
# resetting count 558
# resetting count 559
# resetting count 560
# resetting count 561
# resetting count 562
# resetting count 563
# resetting count 564
# resetting count 565
# resetting count 566
# resetting count 567
# resetting count 568
# resetting count 569
# resetting count 570
# resetting count 571
# resetting count 572
# resetting count 573
# resetting count 574
# resetting count 575
# resetting count 576
# resetting count 577
# resetting count 578
# resetting count 579
# resetting count 580
# resetting count 581
# resetting count 582
# resetting count 583
# resetting count 584
# resetting count 585
# resetting count 586
# resetting count 587
# resetting count 588
# resetting count 589
# resetting count 590
# resetting count 591
# resetting count 592
# resetting count 593
# resetting count 594
# resetting count 595
# resetting count 596
# resetting count 597
# resetting count 598
# resetting count 599
# resetting count 600
# resetting count 601
# resetting count 602
# resetting count 603
# resetting count 604
# resetting count 605
# resetting count 606
# resetting count 607
# resetting count 608
# resetting count 609
# resetting count 610
# resetting count 611
# resetting count 612
# resetting count 613
# resetting count 614
# resetting count 615
# resetting count 616
# resetting count 617
# resetting count 618
# resetting count 619
# resetting count 620
# resetting count 621
# resetting count 622
# resetting count 623
# resetting count 624
# resetting count 625
# resetting count 626
# resetting count 627
# resetting count 628
# resetting count 629
# resetting count 630
# resetting count 631
# resetting count 632
# resetting count 633
# resetting count 634
# resetting count 635
# resetting count 636
# resetting count 637
# resetting count 638
# resetting count 639
# resetting count 640
# resetting count 641
# resetting count 642
# resetting count 643
# resetting count 644
# resetting count 645
# resetting count 646
# resetting count 647
# resetting count 648
# resetting count 649
# resetting count 650
# resetting count 651
# resetting count 652
# resetting count 653
# resetting count 654
# resetting count 655
# resetting count 656
# resetting count 657
# resetting count 658
# resetting count 659
# resetting count 660
# resetting count 661
# resetting count 662
# resetting count 663
# resetting count 664
# resetting count 665
# resetting count 666
# resetting count 667
# resetting count 668
# resetting count 669
# resetting count 670
# resetting count 671
# resetting count 672
# resetting count 673
# resetting count 674
# resetting count 675
# resetting count 676
# resetting count 677
# resetting count 678
# resetting count 679
# resetting count 680
# resetting count 681
# resetting count 682
# resetting count 683
# resetting count 684
# resetting count 685
# resetting count 686
# resetting count 687
# resetting count 688
# resetting count 689
# resetting count 690
# resetting count 691
# resetting count 692
# resetting count 693
# resetting count 694
# resetting count 695
# resetting count 696
# resetting count 697
# resetting count 698
# resetting count 699
# resetting count 700
# resetting count 701
# resetting count 702
# resetting count 703
# resetting count 704
# resetting count 705
# resetting count 706
# resetting count 707
# resetting count 708
# resetting count 709
# resetting count 710
# resetting count 711
# resetting count 712
# resetting count 713
# resetting count 714
# resetting count 715
# resetting count 716
# resetting count 717
# resetting count 718
# resetting count 719
# resetting count 720
# resetting count 721
# resetting count 722
# resetting count 723
# resetting count 724
# resetting count 725
# resetting count 726
# resetting count 727
# resetting count 728
# resetting count 729
# resetting count 730
# resetting count 731
# resetting count 732
# resetting count 733
# resetting count 734
# resetting count 735
# resetting count 736
# resetting count 737
# resetting count 738
# resetting count 739
# resetting count 740
# resetting count 741
# resetting count 742
# resetting count 743
# resetting count 744
# resetting count 745
# resetting count 746
# resetting count 747
# resetting count 748
# resetting count 749
# resetting count 750
# resetting count 751
# resetting count 752
# resetting count 753
# resetting count 754
# resetting count 755
# resetting count 756
# resetting count 757
# resetting count 758
# resetting count 759
# resetting count 760
# resetting count 761
# resetting count 762
# resetting count 763
# resetting count 764
# resetting count 765
# resetting count 766
# resetting count 767
# resetting count 768
# resetting count 769
# resetting count 770
# resetting count 771
# resetting count 772
# resetting count 773
# resetting count 774
# resetting count 775
# resetting count 776
# resetting count 777
# resetting count 778
# resetting count 779
# resetting count 780
# resetting count 781
# resetting count 782
# resetting count 783
# resetting count 784
# resetting count 785
# resetting count 786
# resetting count 787
# resetting count 788
# resetting count 789
# resetting count 790
# resetting count 791
# resetting count 792
# resetting count 793
# resetting count 794
# resetting count 795
# resetting count 796
# resetting count 797
# resetting count 798
# resetting count 799
# resetting count 800
# resetting count 801
# resetting count 802
# resetting count 803
# resetting count 804
# resetting count 805
# resetting count 806
# resetting count 807
# resetting count 808
# resetting count 809
# resetting count 810
# resetting count 811

# %%
missing
# Out:
# []

# %%
815330/811
# Out:
# 1005.3390875462392

# %% [markdown]
# subitted job array to c2:
# ```
# #!/bin/bash
#
# ## set name of PBS job
# #PBS -N mica_array
#
# ## set the job array variable
# #PBS -J 1-812
#
# ## send the environment variables with job
# #PBS -V
#
# ## set the queue
# #PBS -q scgc-route
# #PBS -l walltime=24:00:00
#
# #PBS -l ncpus=20
#
# #PBS -j oe
# #PBS -o /home/julia/out/171229_mica_array/${PBS_ARRAY_INDEX}.out
#
# module load mica
#
# num=$(($PBS_ARRAY_INDEX-1))
#
# echo "My job index is: $PBS_ARRAY_INDEX"
#
# echo $PBS_ARRAY_INDEX
# echo $num
#
# echo running mica $num
#
# mica-search --p='20' --blastp 'blastp' /mnt/scgc/simon/databases/mica/nr-20150620-mica \
# /mnt/scgc/simon/simonsproject/bats248_vs/blastin/bats248_orfs_cdhit90_${num}.fasta \
# --blast-args -outfmt \
# '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore sallseqid score nident positive gaps ppos qframe sframe qseq sseq qlen slen salltitles' \
# -num_alignments 10 -evalue 0.001 \
# -out /mnt/scgc/simon/simonsproject/bats248_vs/blastout/bats248_orfs_cdhit90_${num}.out
# ```
